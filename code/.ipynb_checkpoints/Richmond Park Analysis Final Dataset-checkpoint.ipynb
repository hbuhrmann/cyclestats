# %%
import sys

sys.path

sys.path.append("/Users/hbuhrmann/PycharmProjects/CycleStats")

# %%
import sourcetocsv as cycle

# %%
#filepath = 'C:\\Users\\hanne\\PycharmProjects\\CycleStats\\TestResults\\'


filepath = '/Users/hbuhrmann/PycharmProjects/CycleStats/TestResults2/'
filename= 'richmondpark_final.csv'

cycledf=cycle.getfinalcsvcycledata(filepath,filename)

# %%
import thinkstats2
import thinkplot
import numpy as np

# %%
query = 'LatitudeDegrees >= 51.421213 & LatitudeDegrees <= 51.456435 & LongitudeDegrees >= -0.308058 & LongitudeDegrees <= -0.252830'
richmonddf = cycledf.query(query)

print(f'cycle sample count = {len(cycledf)} and richmond sample count = {len(richmonddf)}')

cycledf.tail()
# Out:
# cycle sample count = 208248 and richmond sample count = 77936
#         Unnamed: 0  RowId       ActivityId                 Time  \
# 208243      416392   1079  _20180514175715  2018-05-14 18:57:19
# 208244      416394   1081  _20180514175715  2018-05-14 18:57:24
# 208245      416396   1083  _20180514175715  2018-05-14 18:57:31
# 208246      416398   1085  _20180514175715  2018-05-14 18:57:37
# 208247      416400   1087  _20180514175715  2018-05-14 18:57:42
#
#         LatitudeDegrees  LongitudeDegrees  DistanceMeters  AltitudeMeters  \
# 208243        51.464290         -0.228006        26.84501           -13.0
# 208244        51.464602         -0.228092        26.88030           -13.4
# 208245        51.464853         -0.228781        26.93222           -15.4
# 208246        51.465117         -0.229157        26.97598           -16.6
# 208247        51.465294         -0.228777        27.00868           -16.8
#
# ...

# %%
#Export the richmond dataset so that it can be inspected in QGIS
richmonddf.to_csv('/Users/hbuhrmann/PycharmProjects/CycleStats/TestResults2/richmondparkonly.csv')

# %%
#Export positive gradients only
query = 'Gradient2 >= 0 & Gradient2 <= 0.15'
richmonddf.query(query).to_csv('/Users/hbuhrmann/PycharmProjects/CycleStats/TestResults2/richmondparkuphill.csv')

# %% [markdown]
# # Probability Mass Functions for level, downhill and uphill

# %%
uphill = richmonddf.query('Speedmps < 20 & Speedmps > 0 & Gradient > 0.01')
level = richmonddf.query('Speedmps < 20 & Speedmps > 0 & Gradient <= 0.01 & Gradient >= -0.01')
downhill = richmonddf.query('Speedmps < 20 & Speedmps > 0 & Gradient < -0.01')

uphillpmf=thinkstats2.Pmf(uphill.Speedmps)
levelpmf=thinkstats2.Pmf(level.Speedmps)
downhillpmf = thinkstats2.Pmf(downhill.Speedmps)

thinkplot.Pmf(levelpmf,label='Level')
thinkplot.Config(xlim=[0,20])
thinkplot.show()

thinkplot.Pmf(uphillpmf,label='Uphill')
thinkplot.Config(xlim=[0,20])
thinkplot.show()

thinkplot.Pmf(downhillpmf,label='Downhill')
thinkplot.Config(xlim=[0,20])
thinkplot.show()

print(f'Level:      Mean: {round(levelpmf.Mean(),3)},  Median: {round(levelpmf.Median(),3)}     Std: {round(levelpmf.Std(),3)}' )
print(f'Uphill:     Mean: {round(uphillpmf.Mean(),3)},  Median: {round(uphillpmf.Median(),3)}     Std: {round(uphillpmf.Std(),3)} ' )
print(f'Downhill:   Mean: {round(downhillpmf.Mean(),3)},  Median: {round(downhillpmf.Median(),3)}     Std: {round(downhillpmf.Std(),3)} ' )
# Out:
# Level:      Mean: 7.826,  Median: 8.098     Std: 2.256
# Uphill:     Mean: 6.554,  Median: 6.621     Std: 1.954
# Downhill:   Mean: 10.05,  Median: 10.06     Std: 2.525

# %% [markdown]
# # Continuous Distribution Function : Level, Uphill, Downhill

# %%
uphillcdf=thinkstats2.Cdf(np.round(uphill.Speedmps,1))
levelcdf=thinkstats2.Cdf(np.round(level.Speedmps,1))
downhillcdf=thinkstats2.Cdf(np.round(downhill.Speedmps,1))



thinkplot.Cdf(levelcdf,label='Level')
thinkplot.Cdf(uphillcdf,label='Uphill')
thinkplot.Cdf(downhillcdf,label='Downhill')
thinkplot.Config(xlim=[0,20])
thinkplot.show()

print(f'Level:      5th Perc: {levelcdf.Percentile(5)}      Median: {levelcdf.Percentile(50)}   95th Perc: {levelcdf.Percentile(95)}' )
print(f'Uphill:     5th Perc: {uphillcdf.Percentile(5)}      Median: {uphillcdf.Percentile(50)}   95th Perc: {uphillcdf.Percentile(95)}' )
print(f'Downhill:     5th Perc: {downhillcdf.Percentile(5)}      Median: {downhillcdf.Percentile(50)}   95th Perc: {downhillcdf.Percentile(95)}' )
# Out:
# Level:      5th Perc: 3.7      Median: 8.1   95th Perc: 11.1
# Uphill:     5th Perc: 3.4      Median: 6.6   95th Perc: 9.6
# Downhill:     5th Perc: 5.6      Median: 10.1   95th Perc: 14.1

# %% [markdown]
# # Now lets focus on uphills between 4% and 6%
#
# Try and answer question : Is there a correllation between speed and cadence?

# %%
steepuphill = richmonddf.query('Speedmps2 < 20 & Speedmps2 > 1 and Gradient2 > 0.06')
uphill = richmonddf.query('Speedmps2 < 20 & Speedmps2 > 1 and Gradient2 >= 0.01 and Gradient2 <= 0.06')
level = richmonddf.query('Speedmps < 20 & Speedmps2 > 1 and Gradient2 < 0.01 and Gradient2 > -0.01')
downhill = richmonddf.query('Speedmps < 20 & Speedmps > 1 and Gradient >= -0.06 and Gradient <= -0.01')
steepdownhill = richmonddf.query('Speedmps < 20 & Speedmps > 1 and Gradient < -0.06')

uphillcdf=thinkstats2.Cdf(np.round(uphill.Speedmps,1))
levelcdf=thinkstats2.Cdf(np.round(level.Speedmps,1))
downhillcdf=thinkstats2.Cdf(np.round(downhill.Speedmps,1))
steepuphillcdf=thinkstats2.Cdf(np.round(steepuphill.Speedmps,1))
steepdownhillcdf=thinkstats2.Cdf(np.round(steepdownhill.Speedmps,1))

thinkplot.Cdf(levelcdf,label='Level')
thinkplot.Cdf(uphillcdf,label='Uphill')
thinkplot.Cdf(steepuphillcdf,label='Steep Uphill')
thinkplot.Cdf(downhillcdf,label='Downhill')
thinkplot.Cdf(steepdownhillcdf,label='Steep Downhill')
thinkplot.Config(xlim=[0,20],xlabel='Speed')
thinkplot.show()

print(f'Steep Uphill:     5th Perc: {steepuphillcdf.Percentile(5)}      Median: {steepuphillcdf.Percentile(50)}   95th Perc: {steepuphillcdf.Percentile(95)}     sample size: {len(steepuphill)}' )
print(f'Uphill:     5th Perc: {uphillcdf.Percentile(5)}      Median: {uphillcdf.Percentile(50)}   95th Perc: {uphillcdf.Percentile(95)}     sample size: {len(uphill)}' )
print(f'Level:      5th Perc: {levelcdf.Percentile(5)}      Median: {levelcdf.Percentile(50)}   95th Perc: {levelcdf.Percentile(95)}     sample size: {len(level)}' )
print(f'Downhill:     5th Perc: {downhillcdf.Percentile(5)}      Median: {downhillcdf.Percentile(50)}   95th Perc: {downhillcdf.Percentile(95)}     sample size: {len(downhill)}' )
print(f'SteepDownhill:     5th Perc: {steepdownhillcdf.Percentile(5)}      Median: {steepdownhillcdf.Percentile(50)}   95th Perc: {steepdownhillcdf.Percentile(95)}     sample size: {len(steepdownhill)}' )

print (f'Total sample size = {len(richmonddf)}')
# Out:
# Steep Uphill:     5th Perc: 3.0      Median: 5.4   95th Perc: 8.8     sample size: 12981
# Uphill:     5th Perc: 4.5      Median: 7.5   95th Perc: 9.9     sample size: 17347
# Level:      5th Perc: 4.1      Median: 8.1   95th Perc: 11.1     sample size: 22264
# Downhill:     5th Perc: 6.5      Median: 10.0   95th Perc: 13.5     sample size: 17544
# SteepDownhill:     5th Perc: 4.6      Median: 10.5   95th Perc: 14.9     sample size: 7176
# Total sample size = 77936

# %% [markdown]
# # Lets do a scatterplot cadence vs speed for a gradient range

# %%
steepuphill2 = steepuphill[steepuphill['Cadence'].notnull()]

uphill2 = uphill[uphill['Cadence'].notnull()]

# %%
#temphist=thinkstats2.Hist(steepuphill.Cadence)

thinkplot.scatter(xs = steepuphill2.Cadence,ys=steepuphill2.Speedmps,alpha=0.01)
thinkplot.config(xlabel='Cadence',ylabel='Speedmps')
thinkplot.show()

thinkplot.scatter(xs= steepuphill2.Cadence,ys=steepuphill2.Gradient,alpha=0.01)
thinkplot.config(ylim=(0.06,0.2),xlabel='Cadence',ylabel='Gradient')
thinkplot.show()



thinkplot.scatter(xs = uphill2.Cadence,ys=uphill2.Speedmps,alpha=0.1)
thinkplot.config(ylim=(7,10),xlim=(50,150),xlabel='Cadence',ylabel='Speedmps')
thinkplot.show()

thinkplot.scatter(xs= uphill2.Cadence,ys=uphill2.Gradient,alpha=0.1)
thinkplot.config(ylim=(0.04,0.06),xlim=(50,150),xlabel='Cadence',ylabel='Gradient')
thinkplot.show()

#Scatterplot for cadence vs gradient, all gradients

# %% [markdown]
# # Scatterplot Cadence vs Gradient

# %%
query = 'Cadence > 0 & Speedmps > 0 & Cadence < 130 and Gradient < 0.2 and Gradient > -0.2'
richmondcadencedf = richmonddf.query(query)

print (f'Sample size of Richmond records with cadence and speed {len(richmondcadencedf)}')

print(f'Number of rides = {len(richmondcadencedf.ActivityId.value_counts())}')
# Out:
# Sample size of Richmond records with cadence and speed 59710
# Number of rides = 172

# %%
thinkplot.scatter(xs = richmondcadencedf.Cadence,ys=richmondcadencedf.Gradient,alpha=0.01)
thinkplot.config(xlabel='Cadence',ylabel='Gradient')
thinkplot.show()

# %%
query = 'Cadence > 0 & Speedmps2 > 0 & Speedmps2 <= 20 & Cadence < 130 and Gradient2 < 0.01 and Gradient2 > -0.01'
richmondcadencedf = richmonddf.query(query)

print (f'Sample size of Richmond records with cadence and speed {len(richmondcadencedf)}')

print(f'Number of rides = {len(richmondcadencedf.ActivityId.value_counts())}')

print(f'Mean = {round(richmondcadencedf.Speedmps.mean(),3)},   Median={round(richmondcadencedf.Speedmps.median(),3)},   Std={round(richmondcadencedf.Speedmps.std(),3)}')
# Out:
# Sample size of Richmond records with cadence and speed 16813
# Number of rides = 172
# Mean = 8.203,   Median=8.347,   Std=1.83

# %%
thinkplot.scatter(xs = richmondcadencedf.Cadence,ys=richmondcadencedf.Gradient2,alpha=0.01)
thinkplot.config(xlabel='Cadence',ylabel='Gradient',title='Scatterplot : Gradient vs Speed for level roads')
thinkplot.show()

cadencecdf = thinkstats2.Cdf(richmondcadencedf.Cadence,label='Cadence on level road')
thinkplot.Cdf(cadencecdf)
thinkplot.config(title='CDF for cadence on level road',xlabel='Cadence')
thinkplot.Show()

cadencecdf = thinkstats2.Cdf(richmondcadencedf.Speedmps2,label='Speed on level road')
thinkplot.Cdf(cadencecdf)
thinkplot.config(title='CDF for speed on level road',xlabel='Speedmps')
thinkplot.Show()

# %%
#The distribution of speed looks like a normal distribution, lets compare it against a normal probability plot

mean = richmondcadencedf.Speedmps2.mean()
median=richmondcadencedf.Speedmps2.median()
std=richmondcadencedf.Speedmps2.std()

xs = [-4,4]
fxs,fys = thinkstats2.FitLine(xs,inter=mean,slope=std)

thinkplot.Plot(fxs,fys, color = 'gray', label = 'model')

xs,ys=thinkstats2.NormalProbability(richmondcadencedf.Speedmps2)

thinkplot.Plot(xs,ys,label = 'Speedmps')

#And it is definitely a normal distribution

# %%
#Lets see if the distribution is consistent over all gradients

min_gr = 0.09
max_gr = 0.12
min_gr_qstr = str(min_gr)
max_gr_qstr = str(max_gr)
min_dstr = str(round(min_gr*100,1))+'%'
max_dstr = str(round(max_gr*100,1))+'%'

query = 'Cadence > 0 & Speedmps2 > 0 & Speedmps2 <= 20 & Cadence < 130 and Gradient2 >= '+min_gr_qstr+' and Gradient2 <= '+max_gr_qstr
upcadf = richmonddf.query(query)

print(f'Gradients between {min_dstr} and {max_dstr}')

print (f'Sample size of Richmond records with cadence and speed {len(upcadf)}')

print(f'Number of rides = {len(upcadf.ActivityId.value_counts())}')

print(f'Mean = {round(upcadf.Speedmps2.mean(),3)},   Median={round(upcadf.Speedmps2.median(),3)},   Std={round(upcadf.Speedmps2.std(),3)}')

#SCATTERPLOT CADENCE AND GRADIENT
thinkplot.scatter(xs = upcadf.Cadence,ys=upcadf.Gradient2,alpha=0.01)
thinkplot.config(xlabel='Cadence',ylabel='Gradient',title='Scatterplot : Cadence vs Gradient for sections  between '+min_dstr+' and '+max_dstr)
thinkplot.show()

#SCATTERPLOT SPEED AND GRADIENT
thinkplot.scatter(xs = upcadf.Speedmps,ys=upcadf.Gradient2,alpha=0.01)
thinkplot.config(xlabel='Speedmps',ylabel='Gradient',title='Scatterplot : Gradient vs Speed for sections  between '+min_dstr+' and '+max_dstr)
thinkplot.show()


#CDF CADENCE
cadencecdf = thinkstats2.Cdf(upcadf.Cadence,label='Cadence between '+min_dstr+' and '+max_dstr)
thinkplot.Cdf(cadencecdf)
thinkplot.config(title='CDF for cadence between '+min_dstr+' and '+max_dstr,xlabel='Cadence')
thinkplot.Show()

#CDF SPEED
cadencecdf = thinkstats2.Cdf(upcadf.Speedmps2,label='Speed on sections  between '+min_dstr+' and '+max_dstr)
thinkplot.Cdf(cadencecdf)
thinkplot.config(title='CDF for speed on sections between '+min_dstr+' and '+max_dstr,xlabel='Speedmps')
thinkplot.Show()

#NORMAL DISTIBRUTION FIT USING THE MEAN AND STD OF THE DATA
mean = upcadf.Speedmps2.mean()
median=upcadf.Speedmps2.median()
std=upcadf.Speedmps2.std()

xs = [-4,4]
fxs,fys = thinkstats2.FitLine(xs,inter=mean,slope=std)

thinkplot.Plot(fxs,fys, color = 'gray', label = 'Model')

xs,ys=thinkstats2.NormalProbability(upcadf.Speedmps2)

thinkplot.Plot(xs,ys,label = 'Speedmps')
thinkplot.Config(title = 'Normal distribution fit for speed on sections between '+min_dstr+' and '+max_dstr)
thinkplot.Show()


#AND LASTLY DO A HISTOGRAM
uphist = thinkstats2.Hist(np.round(upcadf.Speedmps2,1),label='Speedmps')

#for x in sorted(uphist.Items(), key=lambda kv: kv[0]):
#    print (x)

thinkplot.Hist(uphist)
thinkplot.Config(title='Histogram of speeds for a gradient  between '+min_dstr+' and '+max_dstr)
thinkplot.Show()
# Out:
# Gradients between 9.0% and 12.0%
# Sample size of Richmond records with cadence and speed 2595
# Number of rides = 166
# Mean = 4.811,   Median=4.432,   Std=1.333

# %%
#Export the dataset so that it can be inspected in QGIS
upcadf.to_csv('/Users/hbuhrmann/PycharmProjects/CycleStats/TestResults/richmond0to12perc.csv')

# %%
#The data above looks a bit  weird, I would have assumed a more continuous distribution
#this might be because the dataset covers a very small geographic area

#Lets see what it does with my whole of East Sussex Dataset, starting with a slightly smaller bit


filepath = '/Users/hbuhrmann/PycharmProjects/CycleStats/TestResults/'
filename= 'east_sussex.csv'

cycledf=cycle.getfinalcsvcycledata(filepath,filename)

#Limit the dataset to Hastings/Seven Sisters

query = 'LatitudeDegrees >= 50.731827 & LatitudeDegrees <= 50.960866 & LongitudeDegrees >= 0.067130 & LongitudeDegrees <= 0.745465'
hastingsdf = cycledf.query(query)

print(f'cycle sample count = {len(cycledf)} and hastings sample count = {len(hastingsdf)}')

cycledf.tail()
# Out:
# cycle sample count = 794230 and hastings sample count = 548279
#         Unnamed: 0                   RowId       ActivityId  \
# 794225      794225  20180715090548_0001017  _20180715090548
# 794226      794226  20180715090548_0001018  _20180715090548
# 794227      794227  20180715090548_0001019  _20180715090548
# 794228      794228  20180715090548_0001020  _20180715090548
# 794229      794229  20180715090548_0001021  _20180715090548
#
#                        Time  LatitudeDegrees  LongitudeDegrees  \
# 794225  2018-07-15 09:58:30        50.950013          0.369176
# 794226  2018-07-15 09:58:35        50.950013          0.369176
# 794227  2018-07-15 09:58:46        50.950013          0.369176
# 794228  2018-07-15 09:58:53        50.950010          0.369164
# 794229  2018-07-15 09:59:02        50.950010          0.369164
#
#         DistanceMeters  EnhancedAltitude  AltitudeMeters  EnhancedSpeed  ...  \
# 794225        22.96094             115.0           115.0            0.0  ...
# ...

# %%
#Lets see if the distribution is consistent over all gradients

hastingsdf = cycledf 

min_gr = 0.05
max_gr = 0.06
min_gr_qstr = str(min_gr)
max_gr_qstr = str(max_gr)
min_dstr = str(round(min_gr*100,1))+'%'
max_dstr = str(round(max_gr*100,1))+'%'
location = 'East Sussex'

query = 'Cadence > 0 & Speedmps > 0 & Speedmps <= 20 & Cadence < 130 and Gradient >= '+min_gr_qstr+' and Gradient <= '+max_gr_qstr
upcadf = hastingsdf.query(query)

print(f'Gradients between {min_dstr} and {max_dstr}')

print (f'Sample size of {location} records with cadence and speed {len(upcadf)}')

print(f'Number of rides = {len(upcadf.ActivityId.value_counts())}')

print(f'Mean = {round(upcadf.Speedmps.mean(),3)},   Median={round(upcadf.Speedmps.median(),3)},   Std={round(upcadf.Speedmps.std(),3)}')

thinkplot.Clf()

minY=upcadf.Gradient.min()
maxY=upcadf.Gradient.max()

#SCATTERPLOT CADENCE AND GRADIENT
thinkplot.scatter(xs = upcadf.Cadence,ys=upcadf.Gradient,alpha=0.01)
thinkplot.config(xlabel='Cadence',ylabel='Gradient',title='Scatterplot : Cadence vs Gradient for sections  between '+min_dstr+' and '+max_dstr)
thinkplot.config(ylim=[minY,maxY])
thinkplot.show()

#SCATTERPLOT SPEED AND GRADIENT
thinkplot.scatter(xs = upcadf.Speedmps,ys=upcadf.Gradient,alpha=0.01)
thinkplot.config(xlabel='Speedmps',ylabel='Gradient',title='Scatterplot : Gradient vs Speed for sections  between '+min_dstr+' and '+max_dstr)
thinkplot.config(ylim=[minY,maxY])
thinkplot.show()

#JITTERY SCATTERPLOT SPEED AND GRADIENT
speed = thinkstats2.Jitter(upcadf.Speedmps,0.25)
gradient = thinkstats2.Jitter(upcadf.Gradient,0.001)
thinkplot.scatter(xs = speed,ys=gradient,alpha=0.01)
thinkplot.config(xlabel='Speedmps',ylabel='Gradient',title='Jittery Scatterplot : Gradient vs Speed for sections  between '+min_dstr+' and '+max_dstr)
thinkplot.config(ylim=[minY,maxY])
thinkplot.show()





#CDF CADENCE
cadencecdf = thinkstats2.Cdf(upcadf.Cadence,label='Cadence between '+min_dstr+' and '+max_dstr)
thinkplot.Cdf(cadencecdf)
thinkplot.config(title='CDF for cadence between '+min_dstr+' and '+max_dstr,xlabel='Cadence')
thinkplot.Show()

#CDF SPEED
cadencecdf = thinkstats2.Cdf(upcadf.Speedmps,label='Speed on sections  between '+min_dstr+' and '+max_dstr)
thinkplot.Cdf(cadencecdf)
thinkplot.config(title='CDF for speed on sections between '+min_dstr+' and '+max_dstr,xlabel='Speedmps')
thinkplot.Show()

#NORMAL DISTIBRUTION FIT USING THE MEAN AND STD OF THE DATA
mean = upcadf.Speedmps.mean()
median=upcadf.Speedmps.median()
std=upcadf.Speedmps.std()

xs = [-4,4]
fxs,fys = thinkstats2.FitLine(xs,inter=mean,slope=std)

thinkplot.Plot(fxs,fys, color = 'gray', label = 'Model')

xs,ys=thinkstats2.NormalProbability(upcadf.Speedmps)

thinkplot.Plot(xs,ys,label = 'Speedmps')
thinkplot.Config(title = 'Normal distribution fit for speed on sections between '+min_dstr+' and '+max_dstr)
thinkplot.Show()


#AND LASTLY DO A HISTOGRAM
uphist = thinkstats2.Hist(np.round(upcadf.Speedmps,1),label='Speedmps')

#for x in sorted(uphist.Items(), key=lambda kv: kv[0]):
#    print (x)

thinkplot.Hist(uphist)
thinkplot.Config(title='Histogram of speeds for a gradient  between '+min_dstr+' and '+max_dstr)
thinkplot.Show()
# Out:
# Gradients between 5.0% and 6.0%
# Sample size of East Sussex records with cadence and speed 28066
# Number of rides = 177
# Mean = 6.412,   Median=6.974,   Std=1.71

# %%
#Lets take the Richmond data and box that into degrees rounded to 3 decimals
import pandas as pd


richmonddf['LatReduced']=np.round(richmonddf.LatitudeDegrees,3)
richmonddf['LongReduced']=np.round(richmonddf.LongitudeDegrees,3)

richmonddf['GeoIndex']=(richmonddf['LatReduced']*100).astype(int).astype(str)+':'+(richmonddf['LongReduced']*100).astype(int).astype(str)

query = 'Cadence > 0 & Speedmps > 0 & Speedmps <= 20 & Cadence < 130 and Gradient >= 0.05 and Gradient <= 0.06'
tempdf = richmonddf.query(query)

print(f'Reduced Latitude Count = {len(tempdf.LatReduced.value_counts())},    Reduced Longitude Count = {len(tempdf.LongReduced.value_counts())}')
print(f'Rowcount = {len(tempdf)},  GeoIndex count = {len(tempdf.GeoIndex.value_counts())}')



#SCATTERPLOT GeoIndex and Speedmps
thinkplot.scatter(xs = tempdf.GeoIndex,ys=tempdf.Speedmps,alpha=0.01)
thinkplot.config(xlabel='Cadence',ylabel='Speedmps',title='Scatterplot : Cadence vs Gradient for sections  between '+min_dstr+' and '+max_dstr)
#thinkplot.config(ylim=[minY,maxY])
thinkplot.show()


#SCATTERPLOT GeoIndex and Speedmps
thinkplot.scatter(xs = tempdf.GeoIndex,ys=tempdf.Speedmps,alpha=0.1)
thinkplot.config(xlabel='Cadence',ylabel='Speedmps',title='Scatterplot : Cadence vs Gradient for sections  between '+min_dstr+' and '+max_dstr)
thinkplot.config(ylim=[6.5,8.5])
thinkplot.show()
# Out:
# Reduced Latitude Count = 36,    Reduced Longitude Count = 52
# Rowcount = 6980,  GeoIndex count = 18

# %%
#Export the dataset so that it can be inspected in QGIS
tempdf.to_csv('/Users/hbuhrmann/PycharmProjects/CycleStats/TestResults/richmond5to6degreduced.csv')

# %%
import time

print(time.time())
# Out:
# 1576755939.4491708

# %%
print(time.time())
# Out:
# 1576755948.892925
